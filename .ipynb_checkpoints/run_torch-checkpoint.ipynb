# %%
# %run run_torch.py
# Out:
# ---Link Debug---
# Link: 1
# Bandwidth: 1333.333333
# Delay: 0.001000
# Queue Delay: 0.002297
# Max Queue Delay: 0.041250
# One Packet Queue Delay: 0.000750
# Link: 2
# Bandwidth: inf
# Delay: 0.001000
# Queue Delay: 0.000000
# Max Queue Delay: 0.000000
# One Packet Queue Delay: 0.000000
# ---Sender Debug---
# Sender: 1
# Rate: 4266.666667
# Sent: 21630
# Acked: 13630
# Lost: 7998
# Min Latency: 0.002
# Qoe : 433
