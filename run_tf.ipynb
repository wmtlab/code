# %%
# %run run_tensorflow.py
# Out:
# ---Link Debug---
# Link: 1
# Bandwidth: 1333.333333
# Delay: 0.001000
# Queue Delay: 0.002571
# Max Queue Delay: 0.041250
# One Packet Queue Delay: 0.000750
# Link: 2
# Bandwidth: inf
# Delay: 0.001000
# Queue Delay: 0.000000
# Max Queue Delay: 0.000000
# One Packet Queue Delay: 0.000000
# ---Sender Debug---
# Sender: 1
# Rate: 7000.000000
# Sent: 40840
# Acked: 18050
# Lost: 22788
# Min Latency: 0.002
# Qoe : 430
